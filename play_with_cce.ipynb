# %% [markdown]
# # Play with CCE+\nThis notebook is a playground to run the basic CLI modules.

# %%
from cce.reasoning_graph import ReasoningGraph
from cce.context_builder import ContextBuilder
from cce.meaning_engine import MeaningEngine
from cce.reflection import Reflector
from cce.theory_bank import TheoryBank
from cce.simulator import Simulator

g = ReasoningGraph()
cb = ContextBuilder(g)
me = MeaningEngine(g)
rf = Reflector(g)

text = "Our world is complex. Systems interact. Thinking deeply requires time."
ids = cb.ingest_text(text)
me.propose_inferences()
print(g.to_dict())
print(rf.explain_edge(list(g.g.edges)[0][0], list(g.g.edges)[0][1]))
